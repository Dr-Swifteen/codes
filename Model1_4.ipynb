# %% [markdown]
# #### 📌 **HİPERPARAMETRELERİ BURADAN AYARLA**

# %%
learning_rate = 1e-4
dropout_rate = 0.55
batch_size = 64
filters = [32, 64, 128, 256]
earlystop_patience = 18
reduce_lr_patience = 14
epochs = 150
target_size = (224, 224)

# %%
import os
import re
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, f1_score,
                             accuracy_score, roc_auc_score, precision_score, recall_score)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization, ReLU,
                                     MaxPooling2D, Dropout, Flatten, Dense)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #### 📁 **1. Görüntü Yolu Listeleme Fonksiyonu**

# %%
#chatgpt
def mammo_gorunumlerini_listele(kok_dizin):
    pattern = re.compile(r'^[A-Z]_\d+_\d+\.(LEFT|RIGHT)_(CC|MLO)\.jpg$', re.IGNORECASE)
    siniflar = ['benign', 'cancer', 'normal']
    yollar, etiketler = [], []
    for cls in siniflar:
        cls_yolu = os.path.join(kok_dizin, cls)
        if not os.path.isdir(cls_yolu):
            continue
        for durum_id in os.listdir(cls_yolu):
            durum_yolu = os.path.join(cls_yolu, durum_id)
            if not os.path.isdir(durum_yolu):
                continue
            for dosya_adi in os.listdir(durum_yolu):
                if pattern.match(dosya_adi):
                    yollar.append(os.path.join(durum_yolu, dosya_adi))
                    etiketler.append(cls)
    return yollar, etiketler

# %% [markdown]
# #### 🧼 **2. Görüntü Ön İşleme**

# %%
def load_and_preprocess(paths, labels, target_size=target_size, method='minmax'):
    X, y = [], []
    label_map = {'normal': 0, 'benign': 1, 'cancer': 2}
    for img_path, lbl in zip(paths, labels):
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, target_size)
        img = img.astype(np.float32)
        if method == 'minmax':
            img /= 255.0
        else:
            img = (img - img.mean()) / (img.std() + 1e-8)
        X.append(img[..., np.newaxis])
        y.append(label_map[lbl])
    return np.array(X), np.array(y)

# %% [markdown]
# #### 🧠 **3. CNN Model Tanımı**

# %%
def _conv_block(inputs, filters):
    x = Conv2D(filters, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x
def create_cnn_model(input_shape=(224, 224, 1), num_classes=3, filters=filters, dropout_rate=dropout_rate):
    inp = Input(shape=input_shape)
    x = _conv_block(inp, filters[0])
    x = MaxPooling2D((2, 2))(x)

    x = _conv_block(x, filters[1])
    x = _conv_block(x, filters[1])
    x = MaxPooling2D((2, 2))(x)
    
    x = _conv_block(x, filters[2])
    x = _conv_block(x, filters[2])
    x = MaxPooling2D((2, 2))(x)
    
    x = _conv_block(x, filters[3])
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    out = Dense(num_classes, activation='softmax')(x)

    return Model(inputs=inp, outputs=out)

# %% [markdown]
# #### 🚂 **4. Model Eğitimi ve Kaydetme**

# %%
if __name__ == '__main__':
    kok_dizin = os.path.join(os.getcwd(), "Project1")
    yollar, etiketler = mammo_gorunumlerini_listele(kok_dizin)
    X, y = load_and_preprocess(yollar, etiketler)

    X_egitim_val, X_test, y_egitim_val, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_egitim_val, y_egitim_val, test_size=0.1, stratify=y_egitim_val, random_state=42)
    np.save("X_test_1_4.npy", X_test)
    np.save("y_test_1_4.npy", y_test)
    model = create_cnn_model()
    model.compile(optimizer=Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    geri_cagirmalar = [
        EarlyStopping(patience=earlystop_patience, restore_best_weights=True),
        ReduceLROnPlateau(patience=reduce_lr_patience, factor=0.5)
    ]
    #chatgpt
    datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True
    )
    #chatgpt
    datagen.fit(X_egitim_val)
    model.fit(datagen.flow(X_egitim_val, pd.get_dummies(y_egitim_val)),
        epochs=epochs, batch_size=batch_size,
        validation_data=(X_val, pd.get_dummies(y_val)),  
        callbacks=geri_cagirmalar, verbose=1)

    olasiliklar = model.predict(X_test)
    esikler = np.linspace(0.4, 0.6, 21)
    en_iyi_f1, en_iyi_T_m, en_iyi_T_b = 0, 0.47, 0.53
    for T_m_aday in esikler:
        for T_b_aday in esikler:
            tahminler = [2 if p[2] >= T_m_aday else 1 if p[1] >= T_b_aday else 0 for p in olasiliklar]
            f1 = f1_score(y_test, tahminler, average='macro')
            if f1 > en_iyi_f1:
                en_iyi_f1, en_iyi_T_m, en_iyi_T_b = f1, T_m_aday, T_b_aday
# Out:
# Epoch 1/150
# 220/220 [==============================] - 29s 105ms/step - loss: 1.4818 - accuracy: 0.4493 - val_loss: 1.0972 - val_accuracy: 0.3471
# Epoch 2/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.9700 - accuracy: 0.4819 - val_loss: 0.9965 - val_accuracy: 0.4808
# Epoch 3/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.9121 - accuracy: 0.5179 - val_loss: 0.8475 - val_accuracy: 0.5107
# Epoch 4/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.8813 - accuracy: 0.5190 - val_loss: 1.0181 - val_accuracy: 0.4324
# Epoch 5/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.8607 - accuracy: 0.5274 - val_loss: 0.7988 - val_accuracy: 0.5249
# Epoch 6/150
# 220/220 [==============================] - 21s 94ms/step - loss: 0.8598 - accuracy: 0.5144 - val_loss: 0.8357 - val_accuracy: 0.5249
# Epoch 7/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.8517 - accuracy: 0.5245 - val_loss: 0.8316 - val_accuracy: 0.5320
# Epoch 8/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.8378 - accuracy: 0.5358 - val_loss: 0.8128 - val_accuracy: 0.5192
# Epoch 9/150
# 220/220 [==============================] - 21s 93ms/step - loss: 0.8219 - accuracy: 0.5393 - val_loss: 1.7816 - val_accuracy: 0.4239
# Epoch 10/150
# 220/220 [==============================] - 21s 96ms/step - loss: 0.7414 - accuracy: 0.5940 - val_loss: 0.6831 - val_accuracy: 0.6344
# Epoch 65/150
# 220/220 [==============================] - 21s 96ms/step - loss: 0.7408 - accuracy: 0.5907 - val_loss: 0.9464 - val_accuracy: 0.5391
# Epoch 66/150
# 220/220 [==============================] - 21s 96ms/step - loss: 0.7386 - accuracy: 0.5983 - val_loss: 0.6985 - val_accuracy: 0.6501
# Epoch 67/150
# 220/220 [==============================] - 21s 95ms/step - loss: 0.7324 - accuracy: 0.5970 - val_loss: 0.6909 - val_accuracy: 0.6657
# Epoch 68/150
# 220/220 [==============================] - 21s 95ms/step - loss: 0.7301 - accuracy: 0.5997 - val_loss: 0.6847 - val_accuracy: 0.6615
# Epoch 69/150
# 220/220 [==============================] - 21s 95ms/step - loss: 0.7320 - accuracy: 0.6011 - val_loss: 0.6912 - val_accuracy: 0.6643
# Epoch 70/150
# 220/220 [==============================] - 21s 95ms/step - loss: 0.7345 - accuracy: 0.6017 - val_loss: 0.8189 - val_accuracy: 0.5960

# %% [markdown]
#  Metirkler**

# %%
nihai_tahminler = [2 if p[2] >= en_iyi_T_m else 1 if p[1] >= en_iyi_T_b else 0 for p in olasiliklar]
print(f"En iyi eşik sınırı: T_m={en_iyi_T_m:.2f}, T_b={en_iyi_T_b:.2f}")
print("en iyi f1 değeri: f1={en_iyi_f1}")
print(classification_report(y_test, nihai_tahminler, target_names=['normal','benign','cancer']))
print(confusion_matrix(y_test, nihai_tahminler))
print("Accuracy:", accuracy_score(y_test, nihai_tahminler))
print("Precision:", precision_score(y_test, nihai_tahminler, average='macro'))
print("Recall:", recall_score(y_test, nihai_tahminler, average='macro'))
try:
    print("AUC:", roc_auc_score(pd.get_dummies(y_test), olasiliklar, average='macro', multi_class='ovr'))
except:
    print("AUC hesaplanamadı (muhtemelen tek sınıf tahmini nedeniyle)")
with open("optimized_thresholds.txt", "w") as f:
    f.write(f"Best T_m: {en_iyi_T_m}\nBest T_b: {en_iyi_T_b}\nBest F1: {en_iyi_f1}")
# Out:
# En iyi eşik sınırı: T_m=0.49, T_b=0.40
# en iyi f1 değeri: f1={en_iyi_f1}
#               precision    recall  f1-score   support
#
#       normal       0.94      0.67      0.78       241
#       benign       0.50      0.75      0.60       268
#       cancer       0.70      0.54      0.61       272
#
#     accuracy                           0.65       781
#    macro avg       0.72      0.65      0.67       781
# weighted avg       0.71      0.65      0.66       781
#
# [[162  78   1]
#  [  5 202  61]
#  [  5 121 146]]
# Accuracy: 0.6530089628681178
# Precision: 0.7158413968061361
# Recall: 0.654231739763472
# AUC: 0.8258118788824474

# %%
#### 💾 **6. Model ve Eşik Kayıtları**

# %%
model_name = "model4.h5"
model.save(model_name)
print(f"Model kaydedildi: {model_name}")
# Out:
# Model kaydedildi: model4.h5
